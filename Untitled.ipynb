# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download en_core_web_lg
# Out:
# Requirement already satisfied: spacy in c:\users\user\anaconda3\lib\site-packages (3.0.3)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (3.0.1)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from spacy) (41.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (4.57.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (3.0.5)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.10.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (0.7.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.22.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.0.1)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.7.3)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.16.5)
# Requirement already satisfied: typing-extensions>=3.7.4; python_version < "3.8" in c:\users\user\anaconda3\lib\site-packages (from spacy) (3.7.4.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\user\anaconda3\lib\site-packages (from spacy) (0.8.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (8.0.1)
# Requirement already satisfied: pathy in c:\users\user\anaconda3\lib\site-packages (from spacy) (0.4.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.4.0)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (0.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (20.9)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\lib\site-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy) (0.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.9.11)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in c:\users\user\anaconda3\lib\site-packages (from pathy->spacy) (3.0.0)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\user\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (2.4.2)
# Requirement already satisfied: more-itertools in c:\users\user\anaconda3\lib\site-packages (from zipp>=0.5->importlib-metadata>=0.20; python_version < "3.8"->spacy) (7.2.0)
# Requirement already satisfied: en-core-web-sm==3.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl#egg=en_core_web_sm==3.0.0 in c:\users\user\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in c:\users\user\anaconda3\lib\site-packages (from en-core-web-sm==3.0.0) (3.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4; python_version < "3.8" in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.7.4.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.16.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.22.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.0)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (41.4.0)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: pathy in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.57.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.6.0)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.3)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.10.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.24.2)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\user\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in c:\users\user\anaconda3\lib\site-packages (from pathy->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\lib\site-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.1.1)
# Requirement already satisfied: more-itertools in c:\users\user\anaconda3\lib\site-packages (from zipp>=0.5->importlib-metadata>=0.20; python_version < "3.8"->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.2.0)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

nlp = spacy.load('en_core_web_sm') #not so fast internet
nlp = spacy.load('en_core_web_lg') #very fast internet

# %%
# tokenization

doc = nlp('I am flying to Manila.')
print([w.text for w in doc])
# Out:
# ['I', 'am', 'flying', 'to', 'Manila', '.']

# %%
# lemmatization

doc = nlp('this product integrates both libraries for downloading and applying patches')

for token in doc:
    print(token.text, token.lemma_)
# Out:
# this this
# product product
# integrates integrate
# both both
# libraries library
# for for
# downloading download
# and and
# applying apply
# patches patch

# %%
# part of speech tagging

doc = nlp('I have flown to Singapore. Iam flying to Manila.')
for token in doc:
    print(token.text, token.pos_, token.tag_)
# Out:
# I PRON PRP
# have AUX VBP
# flown VERB VBN
# to ADP IN
# Singapore PROPN NNP
# . PUNCT .
# Iam NOUN NNS
# flying VERB VBG
# to ADP IN
# Manila PROPN NNP
# . PUNCT .

# %%
spacy.explain('AUX')
# Out:
# 'auxiliary'

# %%
spacy.explain('VBG')
# Out:
# 'verb, gerund or present participle'

# %%
doc
# Out:
# I have flown to Singapore. Iam flying to Manila.

# %%
for token in doc:
    print(token.text, token.lemma_)
# Out:
# I I
# have have
# flown fly
# to to
# Singapore Singapore
# . .
# Iam Iam
# flying fly
# to to
# Manila Manila
# . .

# %%
print([w.text for w in doc if w.tag_=="VBG" or w.tag_=='VB'])
# Out:
# ['flying']

# %%
for sent in doc.sents:
    print([sent[i] for i in range(len(sent))])
# Out:
# [I, have, flown, to, Singapore, .]
# [Iam, flying, to, Manila, .]

# %%
doc = nlp('The Golden Gate Bridge is an iconic landmark in San Francisco.')

print([w.text for w in doc])
# Out:
# ['The', 'Golden', 'Gate', 'Bridge', 'is', 'an', 'iconic', 'landmark', 'in', 'San', 'Francisco', '.']

# %%
with doc.retokenize() as retokenizer:
    retokenizer.merge(doc[1:4])
with doc.retokenize() as retokenizer:
    retokenizer.merge(doc[7:9])

for token in doc:
    print(token.text, token.lemma_, token.pos_)
# Out:
# The the DET
# Golden Gate Bridge Golden Gate Bridge PROPN
# is be AUX
# an an DET
# iconic iconic ADJ
# landmark landmark NOUN
# in in ADP
# San Francisco San Francisco PROPN
# . . PUNCT

# %%
# dependnecy parsing
doc = nlp('I want a green apple.')
for token in doc:
    print(token.text, token.pos_, token.dep_, spacy.explain(token.dep_))
# Out:
# I PRON nsubj nominal subject
# want VERB ROOT None
# a DET det determiner
# green ADJ amod adjectival modifier
# apple NOUN dobj direct object
# . PUNCT punct punctuation

# %%
from spacy import displacy
displacy.serve(doc, style='dep')
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\spacy\displacy\__init__.py:97: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="01f352c09f4442e5a42c0366c5c8f56f-0" class="displacy" width="925" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">want</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">green</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">apple.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-01f352c09f4442e5a42c0366c5c8f56f-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-01f352c09f4442e5a42c0366c5c8f56f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-01f352c09f4442e5a42c0366c5c8f56f-0-1" stroke-width="2px" d="M420,264.5 C420,89.5 745.0,89.5 745.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-01f352c09f4442e5a42c0366c5c8f56f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-01f352c09f4442e5a42c0366c5c8f56f-0-2" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-01f352c09f4442e5a42c0366c5c8f56f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-01f352c09f4442e5a42c0366c5c8f56f-0-3" stroke-width="2px" d="M245,264.5 C245,2.0 750.0,2.0 750.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-01f352c09f4442e5a42c0366c5c8f56f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,266.5 L758.0,254.5 742.0,254.5" fill="currentColor"/>
# </g>
# </svg>
# </figure>
# </body>
# </html></span>
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
# entity recognition

doc = nlp('The firm earned $1.5 million in 2017.')
phrase = ''
for token in doc:
    if token.tag_ == '$':
        phrase = token.text
        i = token.i+1
        while doc[i].tag_ == "CD":
            phrase += doc[i].text + ' '
            i += 1
        phrase = phrase[:-1]
        print(phrase)
# Out:
# $1.5 million

# %%
spacy.explain('CD')
# Out:
# 'cardinal number'

# %%
doc = nlp('The firm earned $1.5 million in 2017, in comparison with $1.2 million in 2016.')
phrase = ''
for token in doc:
    if token.tag_ == '$':
        phrase = token.text
        i = token.i+1
        while doc[i].tag_ == "CD":
            phrase += doc[i].text + ' '
            i += 1
        phrase = phrase[:-1]
        print(phrase)
# Out:
# $1.5 million
# $1.2 million

# %%
doc = nlp('I want to buy a Apple computer.')
from IPython.core.display import display, HTML
from spacy import displacy

html = displacy.render(doc, style='ent', page=True)

display(HTML(html))
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">I want to buy a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  computer.</div>
# </figure>
# </body>
# </html></span>

# %%
spacy.explain('GPE')
# Out:
# 'Countries, cities, states'

# %%
spacy.explain('ORG')
# Out:
# 'Companies, agencies, institutions, etc.'

# %%
# Word Similarity
nlp('apple').similarity(nlp('banana'))
# Out:
# 0.5831844168885263

# %%
nlp('king').similarity(nlp('queen'))
# Out:
# 0.7252610345406867

# %%
doc = nlp('I want a green apple.')
doc.similarity(doc[2:5])
# Out:
# 0.8776482403927138

# %%
doc.similarity(doc)
# Out:
# 1.0
